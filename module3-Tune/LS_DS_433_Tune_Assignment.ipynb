# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# # Train Practice
#
# ## *Data Science Unit 4 Sprint 2 Assignment 3*
#
# Continue to use TensorFlow Keras & a sample of the [Quickdraw dataset](https://github.com/googlecreativelab/quickdraw-dataset) to build a sketch classification model. The dataset has been sampled to only 10 classes and 10000 observations per class. Using your baseline model from yesterday, hyperparameter tune it and report on your highest validation accuracy. Your singular goal today is to achieve the highest accuracy possible.
#
# *Don't forgot to switch to GPU on Colab!*

# %% [markdown]
# ### Hyperparameters to Tune
#
# At a minimum, tune each of these hyperparameters using any strategy we discussed during lecture today:
# - Optimizer
# - Learning Rate
# - Activiation Function
#   - At least 1 subparameter within the Relu activation function
# - Number of Neurons in Hidden Layers
# - Number of Hidden Layers
# - Weight Initialization

# %%
import numpy as np
from sklearn.utils import shuffle

#import train_test_split to create training and testing sets
from sklearn.model_selection import train_test_split
def load_quickdraw10(path):
    """ Function returns train and testing matrices w/ corresponding target vectors  for given data
    returns X_train,X_test, y_train,  y_test"""
    path = np.load('quickdraw10.npz')
    data = path
    X = data['arr_0']
    y = data['arr_1']
    X, y = shuffle(X, y)
    
    return train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train,X_test, y_train, y_test = load_quickdraw10('module3-Tune/quickdraw10.npz')

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((80000, 784), (80000,), (20000, 784), (20000,))

# %%
# import numpy and pandas libararies incase we need to modify data in pandas data frame
import numpy
import pandas as pd
#Help with hyperparameter tunning
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
#Import model required to build model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
#Load models required to build tensor board
#Tensorboard will help us organize our experiments ran on our model
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

import os
import datetime

# %%
# Number of units represented number of neurons
# hp.Discrete( will pick values discretely that is either 10,15, or 30 per run 
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([10,15,30]))
# Represents how much to change the model depending on the error - value too smale may result 
# in a long training process whereas a value to large may result in learning a sub-optimal set of weights too fast
HP_LEARNING_RATE = hp.HParam('learning_rate', hp.RealInterval(0.001,.01))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd','adamax']))
HP_ACTIVATION = hp.HParam('activation',hp.Discrete(['relu','softmax']))
HP_WEIGHTS = hp.HParam('kernel_initializer', hp.Discrete(['random_uniform','random_normal'])) #weights
HP_BIAS = hp.HParam('bias_initializer', hp.Discrete(['zeros','ones'])) # bias                       
#How were going to test how good our model performed
METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
      hparams=[HP_NUM_UNITS, HP_LEARNING_RATE, HP_OPTIMIZER,HP_ACTIVATION,HP_WEIGHTS,HP_BIAS],
      metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')]
  )

# %%
def train_test_model(hparams):
    
 # construct model 
  model = tf.keras.Sequential(
      [tf.keras.layers.Dense(hparams[HP_NUM_UNITS],hparams[HP_ACTIVATION],hparams[HP_WEIGHTS],hparams[HP_BIAS]),
       tf.keras.layers.Dense(10, hparams[HP_ACTIVATION])      
  ])

  opt_name = hparams[HP_OPTIMIZER]
  lr = hparams[HP_LEARNING_RATE]

  if opt_name == 'adam':
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
  elif opt_name == 'sgd':
    opt = tf.keras.optimizers.SGD(learning_rate=lr)
  elif opt_name == 'adamax':
    opt = tf.keras.optimizers.Adamax(learning_rate=lr)  
  else:
    raise ValueError(f'Unexpected optimizer: {opt_name}')

  model.compile(
      optimizer=opt,
      loss='sparse_categorical_crossentropy',
      metrics=['accuracy']
  )
  #train model and test it  
  model.fit(X_train, y_train, epochs=5)
  _, accuracy = model.evaluate(X_test, y_test)



  return accuracy

# %%
def run(run_dir, hparams):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    accuracy = train_test_model(hparams)
    tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 0

# Basically a grid search
for num_units in HP_NUM_UNITS.domain.values:
  for learning_rate in (HP_LEARNING_RATE.domain.min_value,
                        HP_LEARNING_RATE.domain.max_value):
    for optimizer in HP_OPTIMIZER.domain.values:
        for activation in HP_ACTIVATION.domain.values:
            for kernel_initializer in HP_WEIGHTS.domain.values:
                for bias_initializer in HP_BIAS.domain.values:
                  hparams = {
                  HP_NUM_UNITS: num_units,
                  HP_LEARNING_RATE: learning_rate,
                  HP_OPTIMIZER: optimizer,
                  HP_ACTIVATION: activation,
                  HP_WEIGHTS:kernel_initializer,
                  HP_BIAS:bias_initializer,
                  
                  
                       }

                  run_name = f'run-{session_num}'
                  print(f'--- Starting trial: {run_name}')
                  print({param.name: hparams[param] for param in hparams})
                  run('logs/hparams_tuning/' + run_name, hparams)
                  session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 10, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_normal', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 786us/step - loss: 11.0615 - accuracy: 0.0986
# Epoch 2/5
# 2094/2094 [==============================] - 2s 728us/step - loss: 11.0615 - accuracy: 0.0986
# Epoch 3/5
# 2094/2094 [==============================] - 2s 754us/step - loss: 11.0615 - accuracy: 0.0986
# Epoch 4/5
# 2094/2094 [==============================] - 2s 764us/step - loss: 11.0615 - accuracy: 0.0986 1s - loss: 11.0
# Epoch 5/5
# 2094/2094 [==============================] - 1s 685us/step - loss: 11.0615 - accuracy: 0.0986
# 1032/1032 [==============================] - 0s 469us/step - loss: 11.0484 - accuracy: 0.1029
# --- Starting trial: run-1
# {'num_units': 10, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_normal', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 756us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 2/5
# 2094/2094 [==============================] - 1s 689us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 3/5
# 2094/2094 [==============================] - 1s 678us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 4/5
# 2094/2094 [==============================] - 1s 669us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 5/5
# 2094/2094 [==============================] - 1s 710us/step - loss: 2.3026 - accuracy: 0.1008
# 1032/1032 [==============================] - 1s 494us/step - loss: 2.3026 - accuracy: 0.0983
# --- Starting trial: run-2
# {'num_units': 10, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 786us/step - loss: 11.0405 - accuracy: 0.1005
# Epoch 2/5
# 2094/2094 [==============================] - 1s 709us/step - loss: 11.0406 - accuracy: 0.1005
# Epoch 3/5
# 2094/2094 [==============================] - 1s 699us/step - loss: 11.0406 - accuracy: 0.1005
# Epoch 4/5
# 2094/2094 [==============================] - 2s 868us/step - loss: 11.0406 - accuracy: 0.1005
# Epoch 5/5
# 2094/2094 [==============================] - 2s 950us/step - loss: 11.0406 - accuracy: 0.1005
# 1032/1032 [==============================] - 1s 551us/step - loss: 11.0908 - accuracy: 0.0991
# --- Starting trial: run-3
# {'num_units': 10, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 1s 710us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 2/5
# 2094/2094 [==============================] - 1s 707us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 3/5
# 2094/2094 [==============================] - 2s 734us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 4/5
# 2094/2094 [==============================] - 2s 840us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 5/5
# 2094/2094 [==============================] - 2s 893us/step - loss: 2.3026 - accuracy: 0.1008
# 1032/1032 [==============================] - 1s 813us/step - loss: 2.3026 - accuracy: 0.0983
# --- Starting trial: run-4
# {'num_units': 10, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_normal', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s
# Epoch 2/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.9465 - accuracy: 0.2638
# Epoch 3/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.8958 - accuracy: 0.2566
# Epoch 4/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.8845 - accuracy: 0.2640
# Epoch 5/5
# 2094/2094 [==============================] - 2s 895us/step - loss: 1.8595 - accuracy: 0.2669
# 1032/1032 [==============================] - 1s 865us/step - loss: 1.8841 - accuracy: 0.2728
# --- Starting trial: run-47
# {'num_units': 10, 'learning_rate': 0.01, 'optimizer': 'sgd', 'activation': 'softmax', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0808 - accuracy: 0.2219
# Epoch 2/5
# 2094/2094 [==============================] - 2s 923us/step - loss: 1.8759 - accuracy: 0.2645
# Epoch 3/5
# 2094/2094 [==============================] - 2s 907us/step - loss: 1.8237 - accuracy: 0.2677
# Epoch 4/5
# 2094/2094 [==============================] - 2s 956us/step - loss: 1.7841 - accuracy: 0.2679
# Epoch 5/5
# 2094/2094 [==============================] - 2s 995us/step - loss: 1.7702 - accuracy: 0.2734
# 1032/1032 [==============================] - 1s 743us/step - loss: 1.8950 - accuracy: 0.2701
# --- Starting trial: run-48
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_normal', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 12.3852 - accuracy: 0.1008
# Epoch 2/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 12.3852 - accuracy: 0.1008
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 12.3851 - accuracy: 0.1008
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 12.3852 - accuracy: 0.1008A: 1s - lo
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 12.3851 - accuracy: 0.1008A: 0s - loss: 12.3826 - accuracy: 0.10
# 1032/1032 [==============================] - 1s 751us/step - loss: 12.3735 - accuracy: 0.0983
# --- Starting trial: run-49
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_normal', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 2/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 3/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.3026 - accuracy: 0.1008: 0s - loss: 2.3026 - accuracy:
# 1032/1032 [==============================] - 1s 690us/step - loss: 2.3026 - accuracy: 0.0983
# --- Starting trial: run-50
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 11.0535 - accuracy: 0.0986
# Epoch 2/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 11.0535 - accuracy: 0.0986
# Epoch 3/5
# 2094/2094 [==============================] - 2s 973us/step - loss: 11.0536 - accuracy: 0.0986
# Epoch 4/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 11.0535 - accuracy: 0.0986
# Epoch 5/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 11.0535 - accuracy: 0.0986
# 1032/1032 [==============================] - 1s 772us/step - loss: 11.0645 - accuracy: 0.1029
# --- Starting trial: run-51
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'relu', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 2/5
# 2094/2094 [==============================] - 2s 943us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 3/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 4/5
# 2094/2094 [==============================] - 2s 928us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 5/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# 1032/1032 [==============================] - 1s 775us/step - loss: 2.3026 - accuracy: 0.0983
# --- Starting trial: run-52
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_normal', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.8824 - accuracy: 0.3477
# Epoch 2/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.5739 - accuracy: 0.4212
# Epoch 3/5
# 2094/2094 [==============================] - 2s 995us/step - loss: 1.5620 - accuracy: 0.4197
# Epoch 4/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.5193 - accuracy: 0.4313
# Epoch 5/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.4948 - accuracy: 0.4386
# 1032/1032 [==============================] - 1s 934us/step - loss: 1.5001 - accuracy: 0.4351
# --- Starting trial: run-53
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_normal', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.9745 - accuracy: 0.2400
# Epoch 2/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.8436 - accuracy: 0.2539
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.7975 - accuracy: 0.2605
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.7550 - accuracy: 0.2878
# Epoch 5/5
# 2094/2094 [==============================] - 3s 2ms/step - loss: 1.6984 - accuracy: 0.3231: 0s - loss: 1.7003 - accuracy:
# 1032/1032 [==============================] - 1s 1ms/step - loss: 1.6537 - accuracy: 0.3302
# --- Starting trial: run-54
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 4s 2ms/step - loss: 1.8732 - accuracy: 0.3260
# Epoch 2/5
# 2094/2094 [==============================] - 3s 2ms/step - loss: 1.6439 - accuracy: 0.3682
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.6162 - accuracy: 0.3723
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.6016 - accuracy: 0.3738
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.5806 - accuracy: 0.3810
# 1032/1032 [==============================] - 1s 957us/step - loss: 1.6511 - accuracy: 0.3606
# --- Starting trial: run-55
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.9999 - accuracy: 0.2384
# Epoch 2/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.7718 - accuracy: 0.2840
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.7413 - accuracy: 0.2801
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.7284 - accuracy: 0.2862
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.7226 - accuracy: 0.2814
# 1032/1032 [==============================] - 1s 961us/step - loss: 1.7070 - accuracy: 0.2785
# --- Starting trial: run-56
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adamax', 'activation': 'relu', 'kernel_initializer': 'random_normal', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 9.6661 - accuracy: 0.0999
# Epoch 2/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 9.6661 - accuracy: 0.0999
# Epoch 3/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 9.6661 - accuracy: 0.0999
# Epoch 4/5
# 2094/2094 [==============================] - 2s 899us/step - loss: 9.6661 - accuracy: 0.0999
# Epoch 5/5
# 2094/2094 [==============================] - 2s 952us/step - loss: 9.6661 - accuracy: 0.0999
# 1032/1032 [==============================] - 1s 700us/step - loss: 9.6734 - accuracy: 0.1003
# --- Starting trial: run-57
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adamax', 'activation': 'relu', 'kernel_initializer': 'random_normal', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 965us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 2/5
# 2094/2094 [==============================] - 2s 930us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 3/5
# 2094/2094 [==============================] - 2s 963us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 4/5
# 2094/2094 [==============================] - 2s 911us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 5/5
# 2094/2094 [==============================] - 2s 887us/step - loss: 2.3026 - accuracy: 0.1008
# 1032/1032 [==============================] - 1s 623us/step - loss: 2.3026 - accuracy: 0.0983
# --- Starting trial: run-58
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adamax', 'activation': 'relu', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 5.2790 - accuracy: 0.1002
# Epoch 2/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 5.2790 - accuracy: 0.1002
# Epoch 3/5
# 2094/2094 [==============================] - 2s 942us/step - loss: 5.2790 - accuracy: 0.1002
# Epoch 4/5
# 2094/2094 [==============================] - 2s 952us/step - loss: 5.2790 - accuracy: 0.1002
# Epoch 5/5
# 2094/2094 [==============================] - 2s 874us/step - loss: 5.2790 - accuracy: 0.1002
# 1032/1032 [==============================] - 1s 763us/step - loss: 5.3519 - accuracy: 0.0995
# --- Starting trial: run-59
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adamax', 'activation': 'relu', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 872us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 2/5
# 2094/2094 [==============================] - 2s 850us/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 4/5
# 2094/2094 [==============================] - 3s 2ms/step - loss: 2.3026 - accuracy: 0.1008
# Epoch 5/5
# 2094/2094 [==============================] - 5s 2ms/step - loss: 2.3026 - accuracy: 0.1008
# 1032/1032 [==============================] - 1s 918us/step - loss: 2.3026 - accuracy: 0.0983
# --- Starting trial: run-60
# {'num_units': 15, 'learning_rate': 0.001, 'optimizer': 'adamax', 'activation': 'softmax', 'kernel_initializer': 'random_normal', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 1.9282 - accuracy: 0.3578
# Epoch 2/5
# 2094/2094 [==============================] - 2s 781us/step - loss: 1.6694 - accuracy: 0.3927
# Epoch 3/5
# 2094/2094 [==============================] - 2s 780us/step - loss: 1.5551 - accuracy: 0.4258
# Epoch 4/5
# 2094/2094 [==============================] - 2s 764us/step - loss: 1.4505 - accuracy: 0.4734
# Epoch 5/5
# 2094/2094 [==============================] - 2s 752us/step - loss: 1.3958 - accuracy: 0.47770s - loss: 1.3997 -
# ...
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.3026 - accuracy: 0.1008
# 1032/1032 [==============================] - 1s 845us/step - loss: 2.3026 - accuracy: 0.09830s - loss: 2.3
# --- Starting trial: run-124
# {'num_units': 30, 'learning_rate': 0.01, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_normal', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.9035 - accuracy: 0.2680
# Epoch 2/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.8229 - accuracy: 0.2778
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.8958 - accuracy: 0.2436
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.9307 - accuracy: 0.2400
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.8604 - accuracy: 0.2576: 0s - loss:
# 1032/1032 [==============================] - 1s 883us/step - loss: 1.7286 - accuracy: 0.2750
# --- Starting trial: run-125
# {'num_units': 30, 'learning_rate': 0.01, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_normal', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0547 - accuracy: 0.1799
# Epoch 2/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0215 - accuracy: 0.1882
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.9970 - accuracy: 0.1856
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 1.9981 - accuracy: 0.1858
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0205 - accuracy: 0.1881
# 1032/1032 [==============================] - 1s 994us/step - loss: 1.9997 - accuracy: 0.1882
# --- Starting trial: run-126
# {'num_units': 30, 'learning_rate': 0.01, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0599 - accuracy: 0.1853
# Epoch 2/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0439 - accuracy: 0.1816
# Epoch 3/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0454 - accuracy: 0.1837
# Epoch 4/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0604 - accuracy: 0.1839
# Epoch 5/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.0282 - accuracy: 0.1825
# 1032/1032 [==============================] - 1s 908us/step - loss: 2.0881 - accuracy: 0.1779
# --- Starting trial: run-127
# {'num_units': 30, 'learning_rate': 0.01, 'optimizer': 'adam', 'activation': 'softmax', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.2922 - accuracy: 0.1048
# Epoch 2/5
# 2094/2094 [==============================] - 3s 1ms/step - loss: 2.3052 - accuracy: 0.1000
# Epoch 3/5
# 2094/2094 [==============================] - 2s 1ms/step - loss: 2.
# {'num_units': 30, 'learning_rate': 0.01, 'optimizer': 'sgd', 'activation': 'softmax', 'kernel_initializer': 'random_normal', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 808us/step - loss: 2.1583 - accuracy: 0.1847
# Epoch 2/5
# 2094/2094 [==============================] - 2s 792us/step - loss: 2.0656 - accuracy: 0.1823
# Epoch 3/5
# 2094/2094 [==============================] - 2s 780us/step - loss: 2.0340 - accuracy: 0.1851
# Epoch 4/5
# 2094/2094 [==============================] - 2s 787us/step - loss: 2.0168 - accuracy: 0.1892
# Epoch 5/5
# 2094/2094 [==============================] - 2s 794us/step - loss: 2.0120 - accuracy: 0.1890
# 1032/1032 [==============================] - 1s 652us/step - loss: 2.0124 - accuracy: 0.1809
# --- Starting trial: run-142
# {'num_units': 30, 'learning_rate': 0.01, 'optimizer': 'sgd', 'activation': 'softmax', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'ones'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 890us/step - loss: 2.1710 - accuracy: 0.1782
# Epoch 2/5
# 2094/2094 [==============================] - 2s 889us/step - loss: 2.0421 - accuracy: 0.1869
# Epoch 3/5
# 2094/2094 [==============================] - 2s 880us/step - loss: 2.0042 - accuracy: 0.1874
# Epoch 4/5
# 2094/2094 [==============================] - 2s 882us/step - loss: 1.9860 - accuracy: 0.1885
# Epoch 5/5
# 2094/2094 [==============================] - 2s 886us/step - loss: 1.9825 - accuracy: 0.1863
# 1032/1032 [==============================] - 1s 751us/step - loss: 1.9635 - accuracy: 0.1896
# --- Starting trial: run-143
# {'num_units': 30, 'learning_rate': 0.01, 'optimizer': 'sgd', 'activation': 'softmax', 'kernel_initializer': 'random_uniform', 'bias_initializer': 'zeros'}
# Epoch 1/5
# 2094/2094 [==============================] - 2s 936us/step - loss: 2.3049 - accuracy: 0.0998
# Epoch 2/5
# 2094/2094 [==============================] - 2s 911us/step - loss: 2.1660 - accuracy: 0.1763
# Epoch 3/5
# 2094/2094 [==============================] - 2s 900us/step - loss: 2.0695 - accuracy: 0.1831
# Epoch 4/5
# 2094/2094 [==============================] - 2s 870us/step - loss: 2.0182 - accuracy: 0.1900
# Epoch 5/5
# 2094/2094 [==============================] - 2s 899us/step - loss: 1.9972 - accuracy: 0.1878
# 1032/1032 [==============================] - 1s 981us/step - loss: 1.9915 - accuracy: 0.1903

# %%
# !ls
# Out:
# 9_9_2020_LS_DS17_423_Tune_Lecture.ipynb previous_lectures
# LS_DS_433_Tune_Assignment.ipynb         quickdraw10.npz
# logs

# %%
# !ls logs
# Out:
# hparam_tuning  hparams_tuning

# %%
#Visualize Trials
# %tensorboard --logdir logs/hparams_tuning
# Out:
# Reusing TensorBoard on port 6006 (pid 7815), started 8:09:47 ago. (Use '!kill 7815' to kill it.)
#       <iframe id="tensorboard-frame-b5acbdee6463ecd8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b5acbdee6463ecd8");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Stretch Goals
# - Implement Bayesian Hyper-parameter Optimization
# - Select a new dataset and apply a neural network to it.
# - Use a cloud base experiment tracking framework such as weights and biases
# - Research potential architecture ideas for this problem. Try Lenet-10 for example.
